# %%
import pandas as pd
import pickle
import gzip

# %%
from collections import defaultdict
from modul.preprocessing import case_folding, tokenizing, stopword_removal, normalization, stemming
from modul.scoring import cosine_score
from modul.spelling_correction import generate_kgrams, jaccard_coefficient

# %% [markdown]
# # Input

# %%
query = input("Input your query: ")
query
# Out:
# 'Harga minyak dunia hari ini'

# %% [markdown]
# # Preprocessing

# %%
def preprocessing(query: str) -> list:
  query = case_folding(query)
  query = tokenizing(query)
  query = stopword_removal(query)
  query = normalization(query)
  query = stemming(query)
  return query

# %%
query = preprocessing(query)
query
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Adi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['harga', 'minyak', 'dunia']

# %% [markdown]
# # Read Index

# %%
def find_document(query: list) -> pd.DataFrame:
  with gzip.open(filename='index/metadata_index.pkl.gz', mode='rb') as f:
    df: pd.DataFrame = pickle.load(f)
  with gzip.open(filename='index/inverted_index.pkl.gz', mode='rb') as f:
    inverted_index: defaultdict = pickle.load(f)
  relevant_ids = set()
  for term in query:
    if term in inverted_index:
      relevant_ids.update(inverted_index[term])
  result_df = df[df['id'].isin(relevant_ids)]
  return result_df

# %% [markdown]
# # Spelling Correction

# %%
def spelling_correction(query: list) -> list:
  with gzip.open(filename='index/dictionary_index.pkl.gz', mode='rb') as f:
    dictionary_index: dict = pickle.load(f)
  with gzip.open(filename='index/kgram_index.pkl.gz', mode='rb') as f:
    kgram_index: dict = pickle.load(f)
  corrected_query = []
  for word in query:
    query_kgrams = generate_kgrams(word)
    candidate_term_ids = set()
    for kgram in query_kgrams:
      if kgram in kgram_index:
        candidate_term_ids.update(kgram_index[kgram])
    candidate_term_dict = {key: dictionary_index[key] for key in candidate_term_ids if key in dictionary_index}
    best_match: str
    best_score = 0
    candidate_term = list(candidate_term_dict.values())
    for term in candidate_term:
      term_kgrams = generate_kgrams(term)
      score = jaccard_coefficient(query_kgrams, term_kgrams)
      if score > best_score:
        best_match = term
        best_score = score
    corrected_query.append(best_match if best_match else word)
  return corrected_query

# %%
correct_query = spelling_correction(query)
correct_query
# Out:
# ['harga', 'minyak', 'dunia']

# %% [markdown]
# # Process

# %%
if correct_query == query:
  result = find_document(query)
else:
  print(correct_query)
  result = find_document(correct_query)
result
# Out:
#           id        source                                              title  \
# 0         83         tempo  Depo Plumpang Terbakar, Anggota DPR Minta Pert...
# 1         84         tempo  Jokowi Perintahkan Wapres Ma'ruf Amin Tinjau L...
# 3         86         tempo  Tim Dokkes Polri Telah Terima 14 Kantong Jenaz...
# 4         87         tempo  Bamsoet Ajak Komunitas Otomotif Kembangkan Per...
# 5         92         tempo  Korban Tewas Kebakaran Depo Plumpang 17 Orang,...
# ...      ...           ...                                                ...
# 32713  63545         suara  Niat Zakat Fitrah untuk Diri Sendiri dan Kelua...
# 32718  63551       okezone  Mengenal Legiun Asing Pertama di Dunia dan Kip...
# 32720  63553       okezone  Momen Menegangkan Paspamres Nyaris Baku Tembak...
# 32724  63557  cnnindonesia  Cara Menghitung Fidyah Bagi Muslim yang Tak Bi...
# 32727  63560       okezone  Fakta-Fakta TCG Anadolu, Kapal Perang Tak Bera...
#
#                                                      url  \
# 0      https://nasional.tempo.co/read/1698528/depo-pl...
# 1      https://nasional.tempo.co/read/1698522/jokowi-...
# 3      https://nasional.tempo.co/read/1698540/tim-dok...
# 4      https://nasional.tempo.co/read/1698536/bamsoet...
# 5      https://nasional.tempo.co/read/1698585/korban-...
# ...                                                  ...
# 32713  https://www.suara.com/news/2023/04/12/011643/n...
# 32718  https://nasional.okezone.com/read/2023/04/11/3...
# 32720  https://nasional.okezone.com/read/2023/04/12/3...
# 32724  https://www.cnnindonesia.com/ekonomi/202304111...
# 32727  https://news.okezone.com/read/2023/04/11/18/27...
#
#                                                  content  \
# 0      TEMPO.CO, Jakarta - Anggota Komisi VII DPR RI ...
# 1      TEMPO.CO, Jakarta - Presiden Joko Widodo atau ...
# 3      TEMPO.CO, Jakarta - Tim Kedokteran dan Kesehat...
# 4      INFO NASIONAL - Ketua MPR RI sekaligus Ketua U...
# 5      TEMPO.CO, Jakarta - Wakil Presiden Ma'ruf Amin...
# ...                                                  ...
# 32713  Suara.com - Zakat fitrah merupakan kewajiban b...
# 32718  JAKARTA - Koninklijke Nedelandsch Indisch Lege...
# 32720  PASPAMPRES adalah pasukan yang bertugas melaks...
# 32724  Umat muslim wajib berpuasa saat Ramadan tiba. ...
# 32727  ISTANBUL  Turki meluncurkan kapal perang tak b...
#
#                          date  \
# 0      2023-03-04 06:18:13+00
# 1      2023-03-04 06:04:38+00
# 3      2023-03-04 06:44:10+00
# 4      2023-03-04 06:38:57+00
# 5      2023-03-04 09:40:00+00
# ...                       ...
# 32713  2023-04-11 18:16:43+00
# 32718  2023-04-11 19:03:27+00
# 32720  2023-04-11 19:04:00+00
# 32724  2023-04-11 19:20:02+00
# 32727  2023-04-11 20:01:18+00
#
#                                        text_preprocessed
# 0      [depo, plumpang, bakar, anggota, dpr, pertamin...
# 1      [jokowi, perintah, wapres, ma, ruf, amin, tinj...
# 3      [tim, dokkes, polri, terima, 14, kantong, jena...
# 4      [bamsoet, ajak, komunitas, otomotif, kembang, ...
# 5      [korban, tewas, bakar, depo, plumpang, 17, ora...
# ...                                                  ...
# 32713  [niat, zakat, fitrah, keluarga, lengkap, suara...
# 32718  [kenal, legiun, asing, dunia, kiprah, nusantar...
# 32720  [momen, tegang, paspamres, baku, tembak, agen,...
# 32724  [hitung, fidyah, muslim, puasa, umat, muslim, ...
# 32727  [fakta, fakta, tcg, anadolu, kapal, perang, aw...
#
# [9900 rows x 7 columns]

# %% [markdown]
# # Scoring

# %%
def scoring_document(query: list, result: pd.DataFrame, top_k: int = 10):
  with gzip.open(filename='index/dictionary_index.pkl.gz', mode='rb') as f:
    dictionary_index: dict = pickle.load(f)
  with gzip.open(filename='index/tfidf_index.pkl.gz', mode='rb') as f:
    tfidf_index: defaultdict = pickle.load(f)
  return cosine_score(query, result, dictionary_index, tfidf_index, top_k)

# %%
result = scoring_document(correct_query, result, top_k=10)
result
# Out:
# c:\Users\Adi\Downloads\Project-IR\modul\scoring.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_results['cosine_score'] = pd.Series(top_results['id'].map(dict(top_docs)))
#           id         source  \
# 15628  28749  cnbcindonesia
# 14978  31352  cnbcindonesia
# 11663  25522  cnbcindonesia
# 30517  60887        okezone
# 25668  51287       kumparan
# 10254  17562        okezone
# 30618  61078          tempo
# 18774  35566          suara
# 29447  59334   cnnindonesia
# 25978  52078   cnnindonesia
#
#                                                    title  \
# 15628  Minyak Mentah Dunia 'Nyungsep', Harga BBM Apri...
# 14978  Minyak Dunia Ambles, Harga BBM Pertalite Bisa ...
# 11663  Minyak Amrbuk, Harga BBM Pertalite April Bisa ...
# 30517  Harga Pertalite Bisa Turun di Bawah Rp10.000/L...
# 25668  Harga Minyak Dunia Fluktuatif, Aspebindo Saran...
# 10254  Peringkat Kredit Arab Saudi Naik Usai Reformas...
# 30618  Pemerintah Sebut Harga Pertalite Bisa Diturunk...
# 18774  Pidato Menteri Energi AS Jungkalkan Harga Miny...
# 29447          Data Lowongan Kerja AS Tekan Harga Minyak
# 25978         Puas Melesat, Harga Minyak Stabil Pagi Ini
#
#                                                      url  \
# 15628  https://www.cnbcindonesia.com/news/20230322103...
# 14978  https://www.cnbcindonesia.com/news/20230324093...
# 11663  https://www.cnbcindonesia.com/news/20230321111...
# 30517  https://economy.okezone.com/read/2023/04/10/32...
# 25668  https://kumparan.com/kumparanbisnis/harga-miny...
# 10254  https://economy.okezone.com/read/2023/03/18/32...
# 30618  https://bisnis.tempo.co/read/1713428/pemerinta...
# 18774  https://www.suara.com/bisnis/2023/03/24/091819...
# 29447  https://www.cnnindonesia.com/ekonomi/202304050...
# 25978  https://www.cnnindonesia.com/ekonomi/202304040...
#
#                                                  content  \
# 15628  Jakarta, CNBC Indonesia - Saat ini harga minya...
# 14978  Jakarta, CNBC Indonesia - Pemerintah dalam hal...
# 11663  Jakarta, CNBC Indonesia - Pemerintah dalam hal...
# 30517  JAKARTA  Harga BBM Pertalite bisa turun di baw...
# 25668  mentah dunia terus berfluktuasi dalam beberapa...
# 10254  JAKARTA - S&P Global menaikkan peringkat kredi...
# 30618  TEMPO.CO, Jakarta - Direktur Jenderal Minyak d...
# 18774  Suara.com - Harga minyak dunia turun pada Kami...
# 29447  Harga minyak  melemah di awal perdagangan Kami...
# 25978  Harga minyak dunia stabil di awal perdagangan ...
#
#                          date  \
# 15628  2023-03-22 05:10:00+00
# 14978  2023-03-24 03:25:00+00
# 11663  2023-03-21 04:13:35+00
# 30517  2023-04-10 09:49:13+00
# 25668  2023-04-05 07:06:29+00
# 10254  2023-03-18 02:01:49+00
# 30618  2023-04-10 12:32:26+00
# 18774  2023-03-24 02:18:19+00
# 29447  2023-04-06 00:23:24+00
# 25978  2023-04-04 01:42:35+00
#
#                                        text_preprocessed  cosine_score
# 15628  [minyak, mentah, dunia, nyungsep, harga, bbm, ...      0.523786
# 14978  [minyak, dunia, ambles, harga, bbm, pertalite,...      0.501057
# 11663  [minyak, amrbuk, harga, bbm, pertalite, april,...      0.451683
# 30517  [harga, pertalite, turun, rp10, 000, liter, sy...      0.431939
# 25668  [harga, minyak, dunia, fluktuatif, aspebindo, ...      0.415123
# 10254  [peringkat, kredit, arab, saudi, reformasi, se...      0.407341
# 30618  [perin, harga, pertalite, turun, syarat, tempo...      0.403239
# 18774  [pidato, menteri, energi, as, jungkal, harga, ...      0.400374
# 29447  [data, lowong, kerja, as, tekan, harga, minyak...      0.391505
# 25978  [puas, melesat, harga, minyak, stabil, pagi, h...      0.388548
