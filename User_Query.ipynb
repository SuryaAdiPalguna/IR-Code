# %%
import pandas as pd
import pickle
import gzip

# %%
from collections import defaultdict
from modul.preprocessing import case_folding, tokenizing, stopword_removal, normalization, stemming
from modul.scoring import cosine_score
from modul.spelling_correction import generate_kgrams, jaccard_coefficient

# %% [markdown]
# # Input

# %%
query = input("Input your query: ")
query
# Out:
# 'Berita terbaru politik Indonesia'

# %% [markdown]
# # Preprocessing

# %%
def preprocessing(query: str) -> list:
  query = case_folding(query)
  query = tokenizing(query)
  query = stopword_removal(query)
  query = normalization(query)
  query = stemming(query)
  return query

# %%
query = preprocessing(query)
query
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Adi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['berita', 'baru', 'politik', 'indonesia']

# %% [markdown]
# # Read Index

# %%
def find_document(query: list) -> pd.DataFrame:
  with gzip.open(filename='index/metadata_index.pkl.gz', mode='rb') as f:
    df: pd.DataFrame = pickle.load(f)
  with gzip.open(filename='index/inverted_index.pkl.gz', mode='rb') as f:
    inverted_index: defaultdict = pickle.load(f)
  relevant_ids = set()
  for term in query:
    if term in inverted_index:
      relevant_ids.update(inverted_index[term])
  result_df = df[df['id'].isin(relevant_ids)]
  return result_df

# %% [markdown]
# # Spelling Correction

# %%
def spelling_correction(query: list) -> list:
  with gzip.open(filename='index/dictionary_index.pkl.gz', mode='rb') as f:
    dictionary_index: dict = pickle.load(f)
  with gzip.open(filename='index/kgram_index.pkl.gz', mode='rb') as f:
    kgram_index: dict = pickle.load(f)
  corrected_query = []
  for word in query:
    query_kgrams = generate_kgrams(word)
    candidate_term_ids = set()
    for kgram in query_kgrams:
      if kgram in kgram_index:
        candidate_term_ids.update(kgram_index[kgram])
    candidate_term_dict = {key: dictionary_index[key] for key in candidate_term_ids if key in dictionary_index}
    best_match: str
    best_score = 0
    candidate_term = list(candidate_term_dict.values())
    for term in candidate_term:
      term_kgrams = generate_kgrams(term)
      score = jaccard_coefficient(query_kgrams, term_kgrams)
      if score > best_score:
        best_match = term
        best_score = score
    corrected_query.append(best_match if best_match else word)
  return corrected_query

# %%
correct_query = spelling_correction(query)
correct_query
# Out:
# ['berita', 'baru', 'politik', 'indonesia']

# %% [markdown]
# # Process

# %%
if correct_query == query:
  result = find_document(query)
else:
  print(correct_query)
  result = find_document(correct_query)
result
# Out:
#           id         source  \
# 0         83          tempo
# 1         84          tempo
# 2         85          tempo
# 3         86          tempo
# 4         87          tempo
# ...      ...            ...
# 32720  63553        okezone
# 32725  63558  cnbcindonesia
# 32728  63561        okezone
# 32729  63562        okezone
# 32734  63567          tempo
#
#                                                    title  \
# 0      Depo Plumpang Terbakar, Anggota DPR Minta Pert...
# 1      Jokowi Perintahkan Wapres Ma'ruf Amin Tinjau L...
# 2      HNW Mendukung Jamaah Umroh First Travel Dapatk...
# 3      Tim Dokkes Polri Telah Terima 14 Kantong Jenaz...
# 4      Bamsoet Ajak Komunitas Otomotif Kembangkan Per...
# ...                                                  ...
# 32720  Momen Menegangkan Paspamres Nyaris Baku Tembak...
# 32725  Cek Saldo! Sri Mulyani Sudah Transfer THR ke 2...
# 32728  Humor Gus Dur: Puasa Rajab Ala Gus Dur yang Me...
# 32729  Kisah Keji PKI Bantai Pelajar Sekaligus Atlet ...
# 32734          Ini Besaran Biaya Haji 2023 per Embarkasi
#
#                                                      url  \
# 0      https://nasional.tempo.co/read/1698528/depo-pl...
# 1      https://nasional.tempo.co/read/1698522/jokowi-...
# 2      https://nasional.tempo.co/read/1698527/hnw-men...
# 3      https://nasional.tempo.co/read/1698540/tim-dok...
# 4      https://nasional.tempo.co/read/1698536/bamsoet...
# ...                                                  ...
# 32720  https://nasional.okezone.com/read/2023/04/12/3...
# 32725  https://www.cnbcindonesia.com/news/20230411194...
# 32728  https://nasional.okezone.com/read/2023/04/11/3...
# 32729  https://nasional.okezone.com/read/2023/04/11/3...
# 32734  https://bisnis.tempo.co/read/1713966/ini-besar...
#
#                                                  content  \
# 0      TEMPO.CO, Jakarta - Anggota Komisi VII DPR RI ...
# 1      TEMPO.CO, Jakarta - Presiden Joko Widodo atau ...
# 2      INFO NASIONAL - Wakil Ketua MPR RI Dr. H. M. H...
# 3      TEMPO.CO, Jakarta - Tim Kedokteran dan Kesehat...
# 4      INFO NASIONAL - Ketua MPR RI sekaligus Ketua U...
# ...                                                  ...
# 32720  PASPAMPRES adalah pasukan yang bertugas melaks...
# 32725  Jakarta, CNBC Indonesia - Pemerintah melalui K...
# 32728  JAKARTA  Presiden ke-4 RI KH Abdurrahman Wahid...
# 32729  PELAJAR serta atlet peraih emas Pekan Olahraga...
# 32734  TEMPO.CO, Jakarta - Presiden Joko Widodo telah...
#
#                          date  \
# 0      2023-03-04 06:18:13+00
# 1      2023-03-04 06:04:38+00
# 2      2023-03-04 06:18:04+00
# 3      2023-03-04 06:44:10+00
# 4      2023-03-04 06:38:57+00
# ...                       ...
# 32720  2023-04-11 19:04:00+00
# 32725  2023-04-11 19:30:35+00
# 32728  2023-04-11 20:01:29+00
# 32729  2023-04-11 20:04:13+00
# 32734  2023-04-11 20:00:00+00
#
#                                        text_preprocessed
# 0      [depo, plumpang, bakar, anggota, dpr, pertamin...
# 1      [jokowi, perintah, wapres, ma, ruf, amin, tinj...
# 2      [hnw, dukung, jamaah, umroh, first, travel, da...
# 3      [tim, dokkes, polri, terima, 14, kantong, jena...
# 4      [bamsoet, ajak, komunitas, otomotif, kembang, ...
# ...                                                  ...
# 32720  [momen, tegang, paspamres, baku, tembak, agen,...
# 32725  [cek, saldo, sri, mulyani, transfer, thr, 2, 3...
# 32728  [humor, gus, dur, puasa, rajab, ala, gus, dur,...
# 32729  [kisah, keji, pki, bantai, pelajar, atlet, aih...
# 32734  [besaran, biaya, haji, 2023, embarkasi, tempo,...
#
# [19260 rows x 7 columns]

# %% [markdown]
# # Scoring

# %%
def scoring_document(query: list, result: pd.DataFrame, top_k: int = 10):
  with gzip.open(filename='index/dictionary_index.pkl.gz', mode='rb') as f:
    dictionary_index: dict = pickle.load(f)
  with gzip.open(filename='index/tfidf_index.pkl.gz', mode='rb') as f:
    tfidf_index: defaultdict = pickle.load(f)
  return cosine_score(query, result, dictionary_index, tfidf_index, top_k)

# %%
result = scoring_document(correct_query, result, top_k=10)
result
# Out:
# c:\Users\Adi\Downloads\Project-IR\modul\scoring.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_results['cosine_score'] = pd.Series(top_results['id'].map(dict(top_docs)))
#           id         source  \
# 28934  58348        okezone
# 11114  25157        jawapos
# 34       103          tempo
# 23775  48010   cnnindonesia
# 16737  39854  cnbcindonesia
# 17505  34243       kumparan
# 17771  40476          suara
# 18776  35560        okezone
# 29238  58930       kumparan
# 9267   24848       kumparan
#
#                                                    title  \
# 28934  Usai Bertemu Prabowo, Perindo Sambangi Golkar ...
# 11114  Mahfud Tak Permasalahkan Rumah Ibadah Dijadika...
# 34     Banyak Politikus Pindah Parpol Menjelang Pemil...
# 23775  AHY Sebut RI Dalam Bahaya Jika Ada Intervensi ...
# 16737  Jokowi Pastikan Israel Tetap Ikut Piala Dunia ...
# 17505  Survei Indikator: Ganjar Unggul dalam Simulasi...
# 17771  Survei Indikator: Ganjar Unggul Dalam Simulasi...
# 18776  Mahfud MD Bilang Tempat Ibadah Boleh Digunakan...
# 29238  Pesta Demokrasi Kian Dekat, Bagaimana dengan G...
# 9267   Memahami Sistem Kepartaian Indonesia Pada Masa...
#
#                                                      url  \
# 28934  https://nasional.okezone.com/read/2023/04/08/3...
# 11114  https://www.jawapos.com/nasional/politik/21/03...
# 34     https://nasional.tempo.co/read/1698659/banyak-...
# 23775  https://www.cnnindonesia.com/nasional/20230403...
# 16737  https://www.cnbcindonesia.com/news/20230328194...
# 17505  https://kumparan.com/kumparannews/survei-indik...
# 17771  https://www.suara.com/bisnis/2023/03/27/095955...
# 18776  https://nasional.okezone.com/read/2023/03/26/3...
# 29238  https://kumparan.com/dani-fazli/pesta-demokras...
# 9267   https://kumparan.com/berita-terkini/memahami-s...
#
#                                                  content  \
# 28934  JAKARTA - Usai bertemu Ketua Umum DPP Partai G...
# 11114   Menteri Koordinator Bidang Politik, Hukum dan...
# 34     TEMPO.CO, Jakarta -Pengamat politik Adi Prayit...
# 23775  Ketua Umum Partai Demokrat Agus Harimurti Yudh...
# 16737  Jakarta, CNBC Indonesia - Presiden Joko Widodo...
# 17505  Nama Ganjar Pranowo masih berada di posisi ter...
# 17771  Suara.com - Nama Ganjar Pranowo masih berada d...
# 18776  JAKARTA - Menko Polhukam Mahfud MD mengatakan,...
# 29238  Dalam berbagai berita yang beredar, seperti ya...
# 9267   Sebagaimana yang diketahui, merdeka pada tangg...
#
#                          date  \
# 28934  2023-04-08 06:38:55+00
# 11114  2023-03-21 08:23:07+00
# 34     2023-03-04 15:03:34+00
# 23775  2023-04-03 15:30:09+00
# 16737  2023-03-28 13:30:44+00
# 17505  2023-03-26 10:41:34+00
# 17771  2023-03-27 02:59:55+00
# 18776  2023-03-26 02:40:54+00
# 29238  2023-04-09 12:03:28+00
# 9267   2023-03-21 13:25:29+00
#
#                                        text_preprocessed  cosine_score
# 28934  [bertemu, prabowo, perindo, sambang, golkar, s...      0.283920
# 11114  [mahfud, masalah, rumah, ibadah, jadi, diskusi...      0.263272
# 34     [politikus, pindah, parpol, jelang, milu, amat...      0.248923
# 23775  [ahy, ri, bahaya, intervensi, politik, pk, moe...      0.241230
# 16737  [jokowi, pasti, israel, piala, dunia, u, 20, j...      0.233599
# 17505  [survei, indikator, ganjar, unggul, simulasi, ...      0.232858
# 17771  [survei, indikator, ganjar, unggul, simulasi, ...      0.232554
# 18776  [mahfud, md, bilang, ibadah, giat, politik, ta...      0.232311
# 29238  [pesta, demokrasi, kian, dekat, generasi, muda...      0.227385
# 9267   [paham, sistem, partai, indonesia, demokrasi, ...      0.226347
