# %%
import pandas as pd
import pickle
import gzip

# %%
from collections import defaultdict
from modul.preprocessing import case_folding, tokenizing, stopword_removal, normalization, stemming
from modul.scoring import cosine_score
from modul.spelling_correction import generate_kgrams, jaccard_coefficient

# %% [markdown]
# # Input

# %%
query = input("Input your query: ")
query
# Out:
# 'indonsia majju'

# %% [markdown]
# # Preprocessing

# %%
def preprocessing(query: str) -> list:
  query = case_folding(query)
  query = tokenizing(query)
  query = stopword_removal(query)
  query = normalization(query)
  query = stemming(query)
  return query

# %%
query = preprocessing(query)
query
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Adi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['indonsia', 'majju']

# %% [markdown]
# # Read Index

# %%
def find_document(query: list) -> pd.DataFrame:
  with gzip.open(filename='index/metadata_index.pkl.gz', mode='rb') as f:
    df: pd.DataFrame = pickle.load(f)
  with gzip.open(filename='index/inverted_index.pkl.gz', mode='rb') as f:
    inverted_index: defaultdict = pickle.load(f)
  relevant_ids = set()
  for term in query:
    if term in inverted_index:
      relevant_ids.update(inverted_index[term])
  result_df = df[df['id'].isin(relevant_ids)]
  return result_df

# %% [markdown]
# # Spelling Correction

# %%
def spelling_correction(query: list) -> list:
  with gzip.open(filename='index/dictionary_index.pkl.gz', mode='rb') as f:
    dictionary_index: dict = pickle.load(f)
  with gzip.open(filename='index/kgram_index.pkl.gz', mode='rb') as f:
    kgram_index: dict = pickle.load(f)
  corrected_query = []
  for word in query:
    query_kgrams = generate_kgrams(word)
    candidate_term_ids = set()
    for kgram in query_kgrams:
      if kgram in kgram_index:
        candidate_term_ids.update(kgram_index[kgram])
    candidate_term_dict = {key: dictionary_index[key] for key in candidate_term_ids if key in dictionary_index}
    best_match: str
    best_score = 0
    candidate_term = list(candidate_term_dict.values())
    for term in candidate_term:
      term_kgrams = generate_kgrams(term)
      score = jaccard_coefficient(query_kgrams, term_kgrams)
      if score > best_score:
        best_match = term
        best_score = score
    corrected_query.append(best_match if best_match else word)
  return corrected_query

# %%
correct_query = spelling_correction(query)
correct_query
# Out:
# ['indonsia', 'maju']

# %% [markdown]
# # Process

# %%
if correct_query == query:
  result = find_document(query)
else:
  print(correct_query)
  result = find_document(correct_query)
result
# Out:
# ['indonsia', 'maju']
#           id    source                                              title  \
# 4         87     tempo  Bamsoet Ajak Komunitas Otomotif Kembangkan Per...
# 29       134     tempo  Putusan Penundaan Pemilu 2024, Partai Ummat: J...
# 34       103     tempo  Banyak Politikus Pindah Parpol Menjelang Pemil...
# 49        41     tempo  Dapat Gelar Doktor Honoris Causa, Erick Thohir...
# 63       144     tempo  Prabowo Subianto dan Surya Paloh Bertemu, Demo...
# ...      ...       ...                                                ...
# 32614  63441   okezone  Perindo Sulteng Gelar Buka Bersama dan Bagikan...
# 32626  63467  kumparan  Gelar Safari Ramadhan, Bank BJB Beri Santunan ...
# 32665  63494   okezone  Puluhan Anak Yatim Piatu Yayasan Rasulullah SA...
# 32710  63542  kumparan  Jalin Silaturahmi dan Bangun Kolaborasi Bisnis...
# 32730  63563  kumparan  5 Hewan Aneh yang Hidup di Palung Mariana, Sal...
#
#                                                      url  \
# 4      https://nasional.tempo.co/read/1698536/bamsoet...
# 29     https://nasional.tempo.co/read/1698871/putusan...
# 34     https://nasional.tempo.co/read/1698659/banyak-...
# 49     https://nasional.tempo.co/read/1698341/dapat-g...
# 63     https://nasional.tempo.co/read/1698914/prabowo...
# ...                                                  ...
# 32614  https://news.okezone.com/read/2023/04/11/340/2...
# 32626  https://kumparan.com/kumparanbisnis/gelar-safa...
# 32665  https://megapolitan.okezone.com/read/2023/04/1...
# 32710  https://kumparan.com/TDA/jalin-silaturahmi-dan...
# 32730  https://kumparan.com/kumparansains/5-hewan-ane...
#
#                                                  content  \
# 4      INFO NASIONAL - Ketua MPR RI sekaligus Ketua U...
# 29     TEMPO.CO, Jakarta - Politikus Partai Ummat Mus...
# 34     TEMPO.CO, Jakarta -Pengamat politik Adi Prayit...
# 49     TEMPO.CO, Jakarta - Menteri Badan Usaha Milik ...
# 63     TEMPO.CO, Jakarta - Koordinator Juru Bicara DP...
# ...                                                  ...
# 32614   DONGGALA - Partai Perindo menggelar acara buk...
# 32626  PT Bank Pembangunan Daerah Jawa Barat dan Bant...
# 32665   JAKARTA -  MNC Peduli dan MNC Bank menggelar ...
# 32710  Jakarta Barat - Komunitas Tangan Di Atas (TDA)...
# 32730  menjadi salah satu lubang terdalam dan tergela...
#
#                          date  \
# 4      2023-03-04 06:38:57+00
# 29     2023-03-05 09:42:00+00
# 34     2023-03-04 15:03:34+00
# 49     2023-03-03 14:30:00+00
# 63     2023-03-05 13:05:39+00
# ...                       ...
# 32614  2023-04-11 13:08:44+00
# 32626  2023-04-11 13:32:59+00
# 32665  2023-04-11 14:09:42+00
# 32710  2023-04-11 17:23:43+00
# 32730  2023-04-11 20:13:25+00
#
#                                        text_preprocessed
# 4      [bamsoet, ajak, komunitas, otomotif, kembang, ...
# 29     [putus, tunda, milu, 2024, partai, ummat, bole...
# 34     [politikus, pindah, parpol, jelang, milu, amat...
# 49     [gelar, doktor, honoris, causa, erick, thohir,...
# 63     [prabowo, subianto, surya, paloh, bertemu, dem...
# ...                                                  ...
# 32614  [perindo, sulteng, gelar, buka, bagi, gerobak,...
# 32626  [gelar, safari, ramadhan, bank, bjb, santun, a...
# 32665  [puluh, anak, yatim, piatu, yayasan, rasululla...
# 32710  [jalin, silaturahmi, bangun, kolaborasi, bisni...
# 32730  [5, hewan, aneh, hidup, palung, mariana, salah...
#
# [1932 rows x 7 columns]

# %% [markdown]
# # Scoring

# %%
def scoring_document(query: list, result: pd.DataFrame, top_k: int = 10):
  with gzip.open(filename='index/dictionary_index.pkl.gz', mode='rb') as f:
    dictionary_index: dict = pickle.load(f)
  with gzip.open(filename='index/tfidf_index.pkl.gz', mode='rb') as f:
    tfidf_index: defaultdict = pickle.load(f)
  return cosine_score(query, result, dictionary_index, tfidf_index, top_k)

# %%
result = scoring_document(correct_query, result, top_k=10)
result
# Out:
# c:\Users\Adi\Downloads\Project-IR\deploy\modul\scoring.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_results['cosine_score'] = pd.Series(top_results['id'].map(dict(top_docs)))
#           id         source  \
# 13789  30652       kumparan
# 18182  34946        okezone
# 16438  32977  cnbcindonesia
# 12591  33000  cnbcindonesia
# 17984  34756  cnbcindonesia
# 18510  35294          suara
# 32158  62971       kumparan
# 12156  19452   cnnindonesia
# 11606  30361       kumparan
# 28576  57372       kumparan
#
#                                                    title  \
# 13789  Menhub: Libur dan Cuti Lebaran Jadi 19-25 Apri...
# 18182       Menhub Minta THR Karyawan Cair 18 April 2023
# 16438      Hore! Jokowi Tambah Cuti Bersama Lebaran 2023
# 12591  Cuti Bersama Lebaran Ditambah dan Dimajukan, I...
# 17984  Ini Lho! Alasan Jokowi Tambah Cuti Bersama Leb...
# 18510  Gebrakan Jokowi di Bulan Ramadhan: Larang Peja...
# 32158  Catatan Calon Pendidik: Apakah Masa Depan Masi...
# 12156  Bawaslu Tegaskan Menteri Harus Cuti Jika Ingin...
# 11606  Menhub Sebut Libur dan Cuti Bersama Lebaran 19...
# 28576  Zulhas: Koalisi Besar di Bawah Orkestra Komand...
#
#                                                      url  \
# 13789  https://kumparan.com/kumparanvideo/menhub-libu...
# 18182  https://economy.okezone.com/read/2023/03/24/32...
# 16438  https://www.cnbcindonesia.com/news/20230324155...
# 12591  https://www.cnbcindonesia.com/news/20230324160...
# 17984  https://www.cnbcindonesia.com/news/20230326100...
# 18510  https://www.suara.com/news/2023/03/26/114500/g...
# 32158  https://kumparan.com/nazwa-guseynova-kamila/ca...
# 12156  https://www.cnnindonesia.com/nasional/20230318...
# 11606  https://kumparan.com/kumparannews/menhub-sebut...
# 28576  https://kumparan.com/kumparannews/zulhas-koali...
#
#                                                  content  \
# 13789  Menhub Budi Karya Sumadi mengumumkan cuti bers...
# 18182  JAKARTA - Menteri Perhubungan Budi Karya Sumad...
# 16438  Jakarta, CNBC Indonesia - Menteri Perhubungan ...
# 12591  Jakarta, CNBC Indonesia - Pemerintah telah mem...
# 17984  Jakarta, CNBC Indonesia - Presiden Joko Widodo...
# 18510  Suara.com - Presiden Joko Widodo mengeluarkan ...
# 32158  Pendidikan yang bermutu dan berkualitas merupa...
# 12156  Badan Pengawas Pemilu ( Bawaslu ) menegaskan m...
# 11606  Menhub Budi Karya Sumadi mengumumkan cuti bers...
# 28576  Ketum Zulkifli Hasan (Zulhas) tak menampik ren...
#
#                          date  \
# 13789  2023-03-24 12:51:32+00
# 18182  2023-03-24 10:54:54+00
# 16438  2023-03-24 08:53:10+00
# 12591  2023-03-24 09:06:36+00
# 17984  2023-03-26 04:44:52+00
# 18510  2023-03-26 04:45:00+00
# 32158  2023-04-11 07:42:15+00
# 12156  2023-03-18 08:35:00+00
# 11606  2023-03-24 09:28:03+00
# 28576  2023-04-08 11:26:15+00
#
#                                        text_preprocessed  cosine_score
# 13789  [menhub, libur, cuti, lebaran, 19, 25, april, ...      0.242024
# 18182  [menhub, thr, karyawan, cair, 18, april, 2023,...      0.191224
# 16438  [hore, jokowi, cuti, lebaran, 2023, jakarta, c...      0.184944
# 12591  [cuti, lebaran, tambah, maju, alas, jakarta, c...      0.178775
# 17984  [lho, alas, jokowi, cuti, lebaran, jakarta, cn...      0.174839
# 18510  [gebrakan, jokowi, ramadhan, larang, pejabat, ...      0.173747
# 32158  [catat, calon, didik, butuh, guru, saya, pendi...      0.172458
# 12156  [bawaslu, tegas, menteri, cuti, nyapres, badan...      0.171271
# 11606  [menhub, libur, cuti, lebaran, 19, 25, april, ...      0.161187
# 28576  [zulhas, koalisi, orkestra, komando, jokowi, t...      0.160786
